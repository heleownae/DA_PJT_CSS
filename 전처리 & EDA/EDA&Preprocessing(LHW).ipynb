# %% [markdown]
# # PJT: 금융 CSS(신용평가모델) 개발
# 이해원

# %% [markdown]
# 함수 목록
# - get_loan_month: 대출기간 전처리
# - get_work_year: 근로기간 전처리

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn 

plt.rcParams['font.family'] ='D2Coding'

# %%
train_df = pd.read_csv('C:/Users/LOVE/Downloads/vscode/CSS/train.csv')
test_df = pd.read_csv('C:/Users/LOVE/Downloads/vscode/CSS/test.csv')

train_df
# Out:
#                 ID      대출금액        대출기간       근로기간    주택소유상태       연간소득  \
# 0      TRAIN_00000  12480000   36 months    6 years      RENT   72000000
# 1      TRAIN_00001  14400000   60 months  10+ years  MORTGAGE  130800000
# 2      TRAIN_00002  12000000   36 months    5 years  MORTGAGE   96000000
# 3      TRAIN_00003  14400000   36 months    8 years  MORTGAGE  132000000
# 4      TRAIN_00004  18000000   60 months    Unknown      RENT   71736000
# ...            ...       ...         ...        ...       ...        ...
# 96289  TRAIN_96289  14400000   36 months  10+ years  MORTGAGE  210000000
# 96290  TRAIN_96290  28800000   60 months  10+ years  MORTGAGE  132000000
# 96291  TRAIN_96291  14400000   36 months     1 year  MORTGAGE   84000000
# 96292  TRAIN_96292  15600000   36 months    5 years  MORTGAGE   66330000
# 96293  TRAIN_96293   8640000   36 months  10+ years      RENT   50400000
#
#        부채_대비_소득_비율  총계좌수   대출목적  최근_2년간_연체_횟수    총상환원금     총상환이자  총연체금액  \
# ...

# %%
print(train_df.shape, test_df.shape)
# Out:
# (96294, 15) (64197, 14)

# %% [markdown]
# ## 1. EDA & 전처리

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96294 entries, 0 to 96293
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            96294 non-null  object
#  1   대출금액          96294 non-null  int64
#  2   대출기간          96294 non-null  object
#  3   근로기간          96294 non-null  object
#  4   주택소유상태        96294 non-null  object
#  5   연간소득          96294 non-null  int64
#  6   부채_대비_소득_비율   96294 non-null  float64
#  7   총계좌수          96294 non-null  int64
#  8   대출목적          96294 non-null  object
#  9   최근_2년간_연체_횟수  96294 non-null  int64
#  10  총상환원금         96294 non-null  int64
#  11  총상환이자         96294 non-null  float64
#  12  총연체금액         96294 non-null  float64
#  13  연체계좌수         96294 non-null  float64
#  14  대출등급          96294 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 11.0+ MB

# %% [markdown]
# ### (1) 기술통계 확인

# %%
train_df.describe(include='all')
# Out:
#                  ID          대출금액        대출기간       근로기간    주택소유상태  \
# count         96294  9.629400e+04       96294      96294     96294
# unique        96294           NaN           2         16         4
# top     TRAIN_00000           NaN   36 months  10+ years  MORTGAGE
# freq              1           NaN       64479      31585     47934
# mean            NaN  1.830400e+07         NaN        NaN       NaN
# std             NaN  1.032908e+07         NaN        NaN       NaN
# min             NaN  1.200000e+06         NaN        NaN       NaN
# 25%             NaN  1.020000e+07         NaN        NaN       NaN
# 50%             NaN  1.680000e+07         NaN        NaN       NaN
# 75%             NaN  2.400000e+07         NaN        NaN       NaN
# max             NaN  4.200000e+07         NaN        NaN       NaN
#
#                 연간소득   부채_대비_소득_비율          총계좌수   대출목적  최근_2년간_연체_횟수  \
# count   9.629400e+04  96294.000000  96294.000000  96294  96294.000000
# ...

# %% [markdown]
# 메모
# - 범주형
#     - 대출기간: 2개(36m, 60m). 'months' 삭제
#     - 근로기간: '+', 'years' 등 삭제
#     - 주택소유상태: 4개. 원핫인코딩 (행렬로?) ?
#     - 대출 목적: 12개. 원핫인코딩 (행렬로?) ? 너무 많은 듯
# - 수치형
#     - 최근 2년간 연체 횟수: MAX 30, MIN 0, MEAN 0.3, STD 0.9 -> 이상치 확인
#     - 총연체금액: MAX 75768, MIN 0, MEAN 54, STD 1414 -> 이상치 확인
#     - 연체계좌수: MAX 4, MEAN 0.005, STD 0.079 -> 이상치 확인
# - 대출등급
#     - 수치형으로 변환?
#
# 가설 소스
# 1. 총계좌수-연체계좌수-대출등급
# 2. 부채대비소득비율-대출등급
# 3. 대출금액-연간소득-총상환원금-대출등급

# %% [markdown]
# ### (2) 범주형 자료 확인 & 변환

# %%
for i in train_df[['대출기간', '근로기간', '주택소유상태', '대출목적', '대출등급']].columns:
    print(train_df[i].value_counts())
# Out:
# 대출기간
# 36 months    64479
# 60 months    31815
# Name: count, dtype: int64
# 근로기간
# 10+ years    31585
# 2 years       8450
# < 1 year      7774
# 3 years       7581
# 1 year        6249
# Unknown       5671
# 5 years       5665
# 4 years       5588
# 8 years       4888
# 6 years       3874
# 7 years       3814
# 9 years       3744
# 10+years       896
# <1 year        370
# 3               89
# 1 years         56
# Name: count, dtype: int64
# 주택소유상태
# MORTGAGE    47934
# RENT        37705
# OWN         10654
# ANY             1
# Name: count, dtype: int64
# 대출목적
# 부채 통합     55150
# 신용 카드     24500
# 주택 개선      6160
# 기타         4725
# 주요 구매      1803
# 의료         1039
# 자동차         797
# 소규모 사업      787
# 이사          506
# 휴가          466
# 주택          301
# 재생 에너지       60
# Name: count, dtype: int64
# 대출등급
# B    28817
# C    27623
# A    16772
# D    13354
# E     7354
# F     1954
# G      420
# Name: count, dtype: int64

# %%
# 대출기간
def get_loan_month(mt):
    return int(mt.strip().replace('months', ''))

train_df['대출기간'] = train_df['대출기간'].apply(get_loan_month)
train_df[['대출기간']]
# Out:
#        대출기간
# 0        36
# 1        60
# 2        36
# 3        36
# 4        60
# ...     ...
# 96289    36
# 96290    60
# 96291    36
# 96292    36
# 96293    36
#
# [96294 rows x 1 columns]

# %%
# 근로기간
def get_work_year(yr):
    if yr in ['<1 year', '< 1 year']:
        return 0
    elif yr in ['1 year', '1 years']:
        return 1
    elif yr in ['10+ years', '10+years']:
        return 10
    # 'Unknown'은 NaN으로 대체
    elif yr == 'Unknown':
        return np.nan
    # 그 외는 숫자만 추출
    else:
        return int(''.join(filter(str.isdigit, yr)))

train_df['근로기간'] = train_df['근로기간'].apply(get_work_year)
train_df[['근로기간']]
# Out:
#        근로기간
# 0       6.0
# 1      10.0
# 2       5.0
# 3       8.0
# 4       NaN
# ...     ...
# 96289  10.0
# 96290  10.0
# 96291   1.0
# 96292   5.0
# 96293  10.0
#
# [96294 rows x 1 columns]

# %%
# 시각화
ctgr_list = ['대출기간', '근로기간', '주택소유상태', '대출목적']

def ctgr_value_counts(iumn_name):
    for uniq in list(train_df[iumn_name].unique()):
        cond_unique = (train_df[iumn_name]==uniq)
        print(uniq)
        print(train_df.loc[cond_unique]['대출등급'].value_counts())
        print()

for i in ctgr_list:
    plt.figure(figsize=(10,6))
    sns.countplot(data=train_df, x=i, hue='대출등급', hue_order=['A', 'B', 'C', 'D', 'E', 'F', 'G'])     
    plt.legend(loc='best')
    plt.show()
    ctgr_value_counts(iumn_name=i)
# Out:
# 36
# 대출등급
# B    22883
# C    16935
# A    15952
# D     6485
# E     1895
# F      270
# G       59
# Name: count, dtype: int64
#
# 60
# 대출등급
# C    10688
# D     6869
# B     5934
# E     5459
# F     1684
# A      820
# G      361
# Name: count, dtype: int64
# 6.0
# 대출등급
# B    1157
# C    1124
# A     650
# D     543
# E     296
# F      85
# G      19
# Name: count, dtype: int64
#
# 10.0
# 대출등급
# B    9865
# C    9105
# A    6009
# D    4385
# E    2331
# F     649
# G     137
# Name: count, dtype: int64
#
# 5.0
# 대출등급
# B    1679
# C    1646
# A     986
# D     736
# E     475
# F     119
# G      24
# Name: count, dtype: int64
#
# 8.0
# 대출등급
# B    1417
# C    1364
# A     867
# D     707
# E     385
# F     128
# G      20
# Name: count, dtype: int64
#
# nan
# Series([], Name: count, dtype: int64)
#
# 9.0
# 대출등급
# B    1137
# C    1049
# A     621
# D     545
# E     289
# F      85
# G      18
# Name: count, dtype: int64
#
# 2.0
# 대출등급
# C    2495
# B    2493
# A    1454
# ...

# %%
# 주택소유상태 ANY 1건 확인
train_df.loc[train_df['주택소유상태'] == 'ANY']
# Out:
#                 ID      대출금액  대출기간  근로기간 주택소유상태      연간소득  부채_대비_소득_비율  총계좌수  \
# 28730  TRAIN_28730  41160000    36  10.0    ANY  93600000        17.71    20
#
#       대출목적  최근_2년간_연체_횟수  총상환원금  총상환이자  총연체금액  연체계좌수 대출등급
# 28730   기타             0      0    0.0    0.0    0.0    C

# %% [markdown]
# 메모
# - 주택소유상태
#     - 대출등급이 낮을수록 대출목적 Rent의 비중이 높아짐
#     - ANY 전처리?
# - 대출목적
#     - 부채통합 > 신용카드 >>>>> 주택개선 > 기타
#     - '주택'과 '주택개선'이 따로 있는데 같은 의미?
#     - 신용카드 발급은 높은 대출등급이 많음 = 대출등급이 어느 정도 높아야 신용카드 발급이 가능하기 때문
# - 대출기간, 근로기간(10년 이상 근속 데이터 많음)
#     - 유의미하지 않음

# %% [markdown]
# ### (3) 수치형 자료 확인 & 변환

# %%
train_df.describe()
# Out:
#                대출금액          대출기간          근로기간          연간소득   부채_대비_소득_비율  \
# count  9.629400e+04  96294.000000  90623.000000  9.629400e+04  96294.000000
# mean   1.830400e+07     43.929466      6.007791  9.392672e+07     19.379590
# std    1.032908e+07     11.288582      3.728511  9.956871e+07     33.569559
# min    1.200000e+06     36.000000      0.000000  0.000000e+00      0.000000
# 25%    1.020000e+07     36.000000      2.000000  5.760000e+07     12.650000
# 50%    1.680000e+07     36.000000      6.000000  7.800000e+07     18.740000
# 75%    2.400000e+07     60.000000     10.000000  1.128000e+08     25.540000
# max    4.200000e+07     60.000000     10.000000  1.080000e+10   9999.000000
#
#                총계좌수  최근_2년간_연체_횟수         총상환원금         총상환이자         총연체금액  \
# count  96294.000000  96294.000000  9.629400e+04  9.629400e+04  96294.000000
# mean      25.304827      0.345681  8.225035e+05  4.282282e+05     54.380584
# ...

# %% [markdown]
# #

# %%
# 이상치 확인 (1) 개별 컬럼과 대출등급
num_list = ['대출금액', '연간소득', '부채_대비_소득_비율', '총계좌수', '최근_2년간_연체_횟수', '총상환원금', '총상환이자', '총연체금액', '연체계좌수']
hue_order = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

def num_value_count(df, col):
    statistic_df = pd.DataFrame()

    for level in hue_order:
        level_df = df.loc[(df['대출등급']==level)][[col]].describe().T[['mean', 'std', 'min', 'max']]
        level_df.index = [level]
        statistic_df = pd.concat([statistic_df, level_df], axis=0)

    display(statistic_df)
    print()

for col in num_list:    
    fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(14, 6))
    sns.histplot(data=train_df, x=col, hue='대출등급', ax=ax[0])
    sns.boxplot(data=train_df, y=col, x='대출등급', order=hue_order, ax=ax[1])
    plt.show()
    num_value_count(train_df, col)
# Out:
#            mean           std        min         max
# A  1.790579e+07  9.294000e+06  1200000.0  42000000.0
# B  1.686808e+07  9.772310e+06  1200000.0  42000000.0
# C  1.789053e+07  1.052497e+07  1200000.0  42000000.0
# D  1.953419e+07  1.097270e+07  1200000.0  42000000.0
# E  2.232121e+07  1.077499e+07  1200000.0  42000000.0
# F  2.400517e+07  1.061245e+07  1200000.0  42000000.0
# G  2.402079e+07  1.080393e+07  2310000.0  42000000.0
#            mean           std         min           max
# A  1.124911e+08  1.396115e+08  11424000.0  1.080000e+10
# B  9.570640e+07  1.160385e+08   9600000.0  1.044000e+10
# C  8.904126e+07  7.227851e+07   6432000.0  5.576640e+09
# D  8.360283e+07  6.622191e+07   6528000.0  3.600000e+09
# E  8.494000e+07  5.582025e+07   6000000.0  1.800000e+09
# F  8.434506e+07  4.500624e+07  10627200.0  6.000000e+08
# G  8.258034e+07  5.407082e+07  10555200.0  4.344000e+08
#         mean       std   min     max
# A  16.547850  7.558913  0.00   39.80
# ...

# %%
# 이상치 확인 (2) 개별 컬럼
fig, ax = plt.subplots(3, 3, figsize = (12,9))
i = 0

for row in range(3):
    for col in range(3):
        sns.boxplot(train_df, y = num_list[i], ax = ax[row, col])
        ax[row, col].set_title(num_list[i])
        i += 1

plt.show()

# %%
# 연간소득 확인
train_df.loc[train_df['연간소득'] > 8000000000]
# Out:
#                 ID      대출금액  대출기간  근로기간    주택소유상태         연간소득  부채_대비_소득_비율  \
# 12448  TRAIN_12448  12000000    36   3.0  MORTGAGE   9120000000         0.09
# 38340  TRAIN_38340  14400000    36  10.0  MORTGAGE  10200025200         0.22
# 60715  TRAIN_60715  13200000    36  10.0  MORTGAGE  10800000000         0.08
# 86424  TRAIN_86424  16800000    60  10.0  MORTGAGE  10440000000         0.18
#
#        총계좌수   대출목적  최근_2년간_연체_횟수     총상환원금     총상환이자  총연체금액  연체계좌수 대출등급
# 12448    27  주택 개선            10  12000000  192312.0    0.0    0.0    A
# 38340    21  신용 카드             0    349020   99036.0    0.0    0.0    B
# 60715    29  부채 통합             0    331128   70740.0    0.0    0.0    A
# 86424    32  부채 통합             0    213312  129096.0    0.0    0.0    B

# %%
# 부채대비소득비율 확인 (1)
train_df.loc[train_df['부채_대비_소득_비율'] > 100]
# Out:
#                 ID      대출금액  대출기간  근로기간    주택소유상태      연간소득  부채_대비_소득_비율  \
# 12498  TRAIN_12498   4440000    36   NaN  MORTGAGE         0      9999.00
# 29129  TRAIN_29129  14400000    36   NaN      RENT   1440000       672.52
# 62125  TRAIN_62125  18000000    36   NaN  MORTGAGE  10440000       120.66
# 62765  TRAIN_62765   7860000    36   NaN  MORTGAGE   2124000      1092.52
# 81970  TRAIN_81970  14400000    60   NaN  MORTGAGE  11694000       125.25
# 83954  TRAIN_83954  24000000    60   0.0      RENT  32400000       100.09
#
#        총계좌수   대출목적  최근_2년간_연체_횟수   총상환원금     총상환이자  총연체금액  연체계좌수 대출등급
# 12498    20  신용 카드             2  205356   85884.0    0.0    0.0    C
# 29129    13  부채 통합             0  595344  442860.0    0.0    0.0    E
# 62125    26  부채 통합             0  396456  200328.0    0.0    0.0    D
# 62765    25  신용 카드             2       0       0.0    0.0    0.0    D
# 81970    53  부채 통합             0  302736  412116.0    0.0    0.0    D
# ...

# %%
# 부채대비소득비율 확인 (2)
train_df.loc[train_df['부채_대비_소득_비율'] > 600]
# Out:
#                 ID      대출금액  대출기간  근로기간    주택소유상태     연간소득  부채_대비_소득_비율  \
# 12498  TRAIN_12498   4440000    36   NaN  MORTGAGE        0      9999.00
# 29129  TRAIN_29129  14400000    36   NaN      RENT  1440000       672.52
# 62765  TRAIN_62765   7860000    36   NaN  MORTGAGE  2124000      1092.52
#
#        총계좌수   대출목적  최근_2년간_연체_횟수   총상환원금     총상환이자  총연체금액  연체계좌수 대출등급
# 12498    20  신용 카드             2  205356   85884.0    0.0    0.0    C
# 29129    13  부채 통합             0  595344  442860.0    0.0    0.0    E
# 62765    25  신용 카드             2       0       0.0    0.0    0.0    D

# %% [markdown]
# 메모
# - 대출금액
#     - 등급이 낮을수록 대출금액이 높은 경향성
# - 연간소득
#     - 상환능력
#     - 이상치(>80000000000)가 있지만 부채대비소득비율, 대출등급, 연체횟수 등을 고려하여 처리 X
# - 총상환이자
#     - 등급이 낮을수록 상환이자가 높은 경향성
#     - (절대적) 이자금액이 많다 = (절대적) 대출금액이 많음 or 원금 상환이 오래 걸린다
# - 부채대비소득비율
#     - 이상치(>600) 처리
# - 총계좌수(50개 이상인 데이터 있음), 최근2년간연체횟수(횟수가 많다고 등급이 낮진 않음), 총상환원금, 총연체금액, 연체계좌수
#     - 유의미하지 않음

# %%
# 이상치 처리, ID drop
train_df = train_df.drop(train_df[train_df['부채_대비_소득_비율']>600].index)
train_df = train_df.drop(train_df['ID'], axis = 1)

# %%
train_df.head()
# Out:
#        대출금액  대출기간  근로기간    주택소유상태       연간소득  부채_대비_소득_비율  총계좌수   대출목적  \
# 0  12480000    36   6.0      RENT   72000000        18.90    15  부채 통합
# 1  14400000    60  10.0  MORTGAGE  130800000        22.33    21  주택 개선
# 2  12000000    36   5.0  MORTGAGE   96000000         8.60    14  부채 통합
# 3  14400000    36   8.0  MORTGAGE  132000000        15.09    15  부채 통합
# 4  18000000    60   NaN      RENT   71736000        25.39    19  주요 구매
#
#    최근_2년간_연체_횟수   총상환원금     총상환이자  총연체금액  연체계좌수 대출등급
# 0             0       0       0.0    0.0    0.0    C
# 1             0  373572  234060.0    0.0    0.0    B
# 2             0  928644  151944.0    0.0    0.0    A
# 3             0  325824  153108.0    0.0    0.0    C
# 4             0  228540  148956.0    0.0    0.0    B

# %% [markdown]
# ### (4) 파생변수

# %%
# 대출금_대비_상환이자_비율
train_df2 = train_df.copy()
train_df2['대출금_대비_상환이자_비율'] = train_df2['총상환이자'] / train_df2['대출금액']

sns.histplot(data=train_df2, x='대출금_대비_상환이자_비율')
plt.show()

# %%
# IQR
sns.boxplot(data=train_df2, x='대출등급', y='대출금_대비_상환이자_비율', order=hue_order)
plt.show()

# %% [markdown]
# 메모
# - 대출금 대비 상환이자(=총상환이자(금액)) 비율
#     - 상환율, 잘 갚았는지 기준
#     - 상환율이 낮을수록 대출등급이 높은 경향성
